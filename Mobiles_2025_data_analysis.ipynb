# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\PC\Desktop\DataSet\Mobiles Dataset 2025.csv", encoding='ISO-8859-1')
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    object
#  10  Launched Price (India)     930 non-null    object
#  11  Launched Price (China)     930 non-null    object
#  12  Launched Price (USA)       930 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Company Name                 0
# Model Name                   0
# Mobile Weight                0
# RAM                          0
# Front Camera                 0
# Back Camera                  0
# Processor                    0
# Battery Capacity             0
# Screen Size                  0
# Launched Price (Pakistan)    0
# Launched Price (India)       0
# Launched Price (China)       0
# Launched Price (USA)         0
# Launched Price (Dubai)       0
# Launched Year                0
# dtype: int64

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df['Mobile Weight'] = df['Mobile Weight'].astype(str).str.replace('g', '', regex=False).astype(float)
df['Launched Price (Pakistan)'] = df['Launched Price (Pakistan)'].astype(str).str.replace('PKR', '', regex=False).str.replace(',', '', regex=False).str.strip().replace('Not available', np.nan).astype(float)
df['Launched Price (India)'] = df['Launched Price (India)'].astype(str).str.replace('INR', '', regex=False).str.replace(',', '', regex=False).str.strip().replace('Not available', np.nan).astype(float)
df['Launched Price (China)'] = df['Launched Price (China)'].astype(str).str.replace('CNY', '', regex=False).str.replace('¥', '', regex=False).str.replace(',', '', regex=False).str.strip().replace('Not available', np.nan).astype(float)
df['Launched Price (USA)'] = df['Launched Price (USA)'].astype(str).str.replace('USD', '', regex=False).str.replace('$', '', regex=False).str.replace(',', '', regex=False).str.strip().replace('Not available', np.nan).astype(float)
df['Launched Price (Dubai)'] = df['Launched Price (Dubai)'].astype(str).str.replace('AED', '', regex=False).str.replace(',', '', regex=False).str.strip().replace('Not available', np.nan).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    float64
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  929 non-null    float64
#  10  Launched Price (India)     930 non-null    float64
#  11  Launched Price (China)     930 non-null    float64
#  12  Launched Price (USA)       930 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Mobile Weight  Launched Price (Pakistan)  Launched Price (India)  \
# count     930.000000                 929.000000              930.000000
# mean      228.267097              125436.063509            50576.818280
# std       105.432503              101593.522572            40960.179361
# min       135.000000               15999.000000             5999.000000
# 25%       185.000000               54999.000000            19999.000000
# 50%       194.000000               85000.000000            34999.000000
# 75%       208.000000              179999.000000            74900.000000
# max       732.000000              604999.000000           274999.000000
#
#        Launched Price (China)  Launched Price (USA)  Launched Price (Dubai)  \
# count              930.000000            930.000000              930.000000
# mean              3821.430108            625.515763             2183.933333
# std               2766.076655           1347.561211             1565.631642
# ...

# %%
df
# Out:
#     Company Name            Model Name  Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174.0   6GB             12MP
# 1          Apple       iPhone 16 256GB          174.0   6GB             12MP
# 2          Apple       iPhone 16 512GB          174.0   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203.0   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203.0   6GB             12MP
# ..           ...                   ...            ...   ...              ...
# 925         Poco          Pad 5G 128GB          571.0   8GB              8MP
# 926         Poco          Pad 5G 256GB          571.0   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239.0  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239.0  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239.0  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df.head(10)
# Out:
#   Company Name               Model Name  Mobile Weight  RAM Front Camera  \
# 0        Apple          iPhone 16 128GB          174.0  6GB         12MP
# 1        Apple          iPhone 16 256GB          174.0  6GB         12MP
# 2        Apple          iPhone 16 512GB          174.0  6GB         12MP
# 3        Apple     iPhone 16 Plus 128GB          203.0  6GB         12MP
# 4        Apple     iPhone 16 Plus 256GB          203.0  6GB         12MP
# 5        Apple     iPhone 16 Plus 512GB          203.0  6GB         12MP
# 6        Apple      iPhone 16 Pro 128GB          206.0  6GB    12MP / 4K
# 7        Apple      iPhone 16 Pro 256GB          206.0  8GB    12MP / 4K
# 8        Apple      iPhone 16 Pro 512GB          206.0  8GB    12MP / 4K
# 9        Apple  iPhone 16 Pro Max 128GB          221.0  6GB    12MP / 4K
#
#    Back Camera   Processor Battery Capacity Screen Size  \
# 0         48MP  A17 Bionic         3,600mAh  6.1 inches
# ...

# %%
df.tail(10)
# Out:
#     Company Name            Model Name  Mobile Weight   RAM     Front Camera  \
# 920         POCO          F6 Pro 256GB          210.0   8GB             20MP
# 921         POCO              C65 64GB          190.0   4GB              5MP
# 922         POCO              X7 128GB          195.0   6GB             16MP
# 923         POCO          X7 Pro 256GB          207.0   8GB             20MP
# 924         POCO           M7 5G 128GB          198.0   6GB              8MP
# 925         Poco          Pad 5G 128GB          571.0   8GB              8MP
# 926         Poco          Pad 5G 256GB          571.0   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239.0  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239.0  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239.0  12GB  10MP, 4MP (UDC)
#
#     Back Camera                Processor Battery Capacity  Screen Size  \
# ...

# %%
df
# Out:
#     Company Name            Model Name  Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174.0   6GB             12MP
# 1          Apple       iPhone 16 256GB          174.0   6GB             12MP
# 2          Apple       iPhone 16 512GB          174.0   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203.0   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203.0   6GB             12MP
# ..           ...                   ...            ...   ...              ...
# 925         Poco          Pad 5G 128GB          571.0   8GB              8MP
# 926         Poco          Pad 5G 256GB          571.0   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239.0  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239.0  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239.0  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df_prices = pd.DataFrame({
    "Pakistan": df["Launched Price (Pakistan)"],
    "India": df["Launched Price (India)"],
    "China": df["Launched Price (China)"],
    "USA": df["Launched Price (USA)"],
    "Dubai": df["Launched Price (Dubai)"]
})
df_melted = df_prices.melt(var_name="Country", value_name="Launch Price")
avg_prices = df_melted.groupby("Country")["Launch Price"].mean().reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=avg_prices, x="Country", y="Launch Price")
plt.title("Average Mobile Launch Price by Country", fontsize=14)
plt.ylabel("Average Price (Local Currency)")
plt.xlabel("Country")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
df
# Out:
#     Company Name            Model Name  Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174.0   6GB             12MP
# 1          Apple       iPhone 16 256GB          174.0   6GB             12MP
# 2          Apple       iPhone 16 512GB          174.0   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203.0   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203.0   6GB             12MP
# ..           ...                   ...            ...   ...              ...
# 925         Poco          Pad 5G 128GB          571.0   8GB              8MP
# 926         Poco          Pad 5G 256GB          571.0   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239.0  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239.0  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239.0  12GB  10MP, 4MP (UDC)
#
# ...

# %%
plt.figure(figsize=(14, 6))
sns.set_style("whitegrid")
sns.countplot(data=df, y="Company Name", order=df["Company Name"].value_counts().index)
plt.title("Number of Models per Brand", fontsize=16)
plt.xlabel("Number of Models")
plt.ylabel("Brand")
plt.tight_layout()
plt.show()

# %%
df['RAM (GB)'] = df['RAM'].str.extract(r'(\d+\.?\d*)').astype(float)
df['RAM (GB)']
# Out:
# 0       6.0
# 1       6.0
# 2       6.0
# 3       6.0
# 4       6.0
#        ...
# 925     8.0
# 926     8.0
# 927    12.0
# 928    12.0
# 929    12.0
# Name: RAM (GB), Length: 930, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='RAM (GB)', y='Launched Price (India)', hue='Company Name')
plt.title("Price vs RAM (India)", fontsize=14)
plt.xlabel("RAM (GB)")
plt.ylabel("Launched Price (INR)")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df
# Out:
#     Company Name            Model Name  Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174.0   6GB             12MP
# 1          Apple       iPhone 16 256GB          174.0   6GB             12MP
# 2          Apple       iPhone 16 512GB          174.0   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203.0   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203.0   6GB             12MP
# ..           ...                   ...            ...   ...              ...
# 925         Poco          Pad 5G 128GB          571.0   8GB              8MP
# 926         Poco          Pad 5G 256GB          571.0   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239.0  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239.0  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239.0  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df['Battery Capacity'] = df['Battery Capacity'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)
df['Battery Capacity']
# Out:
# 0         3.0
# 1         3.0
# 2         3.0
# 3         4.0
# 4         4.0
#         ...
# 925      10.0
# 926      10.0
# 927    4400.0
# 928    4400.0
# 929    4400.0
# Name: Battery Capacity, Length: 930, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Battery Capacity'], bins=20, kde=True, color='teal')
plt.title("Battery Capacity Distribution", fontsize=14)
plt.xlabel("Battery Capacity (mAh)")
plt.ylabel("Number of Models")
plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
sns.set_style("whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(18, 12))  # 2 rows, 2 columns
plt.subplots_adjust(hspace=0.4, wspace=0.3)  # spacing between plots
sns.barplot(data=avg_prices, x="Country", y="Launch Price", ax=axes[0, 0])
axes[0, 0].set_title("Average Mobile Launch Price by Country", fontsize=14)
axes[0, 0].set_ylabel("Average Price (Local Currency)")
axes[0, 0].set_xlabel("Country")
axes[0, 0].grid(axis='y', linestyle='--', alpha=0.6)
sns.countplot(data=df, y="Company Name", order=df["Company Name"].value_counts().index, ax=axes[0, 1])
axes[0, 1].set_title("Number of Models per Brand", fontsize=14)
axes[0, 1].set_xlabel("Number of Models")
axes[0, 1].set_ylabel("Brand")
sns.scatterplot(data=df, x='RAM (GB)', y='Launched Price (India)', hue='Company Name', ax=axes[1, 0])
axes[1, 0].set_title("Price vs RAM (India)", fontsize=14)
axes[1, 0].set_xlabel("RAM (GB)")
axes[1, 0].set_ylabel("Launched Price (INR)")
axes[1, 0].legend(bbox_to_anchor=(1.05, 1), loc='upper left', title="Brand")
sns.histplot(df['Battery Capacity'], bins=20, kde=True, color='teal', ax=axes[1, 1])
axes[1, 1].set_title("Battery Capacity Distribution", fontsize=14)
axes[1, 1].set_xlabel("Battery Capacity (mAh)")
axes[1, 1].set_ylabel("Number of Models")
axes[1, 1].grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()
